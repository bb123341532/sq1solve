# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def csrot(layer):
    return sum(2 if x == 'c' else 1 for x in layer)

def csfalg(top, target, alg):
    top_np = np.array(top)
    target_np = np.array(target)

    for i in range(len(top_np)):
        rotat = np.roll(top_np, -i)
        if np.array_equal(rotat, target_np):
            rotsl = target_np[:i]
            tval = csrot(rotsl)
            return f"({tval},0)    {alg}"
        else:
          pass

inputstr = input("Add meg a felső réteg elemeinek az összetételét (pl.: e e e e e c c e e e): ")
current_layer = inputstr.strip().split()

cubeshape = ["e e e e e c c e e e", "e e c e c e e e e e", "e e c e e e e e e c", "c e e e c e e e e e", "e e e c e e e e c e"]
cubeshapealg = ["/(-2,-4)/(-1,-2)/(-3,-3)/","/(2,-2)/(-3,-4)/(4,-3)/(-5,-4)/(6,-3)/","/(-4,-2)/(-1,4)/(-3,0)/","/(-4,0)/(5,4)/(2,-3)/(-5,-4)/(6,-3)/","/(2,2)/(0,-1)/(3,3)/"]

for i in range(len(cubeshape)):
  shalg = csfalg(current_layer, cubeshape[i].split(' '), cubeshapealg[i])
  if shalg:
    print(shalg)

def rotlayer(layer, steps):
    return layer[-steps:] + layer[:-steps]

def arots(lstr):
    layer = lstr.split()
    return [rotlayer(layer, i) for i in range(len(layer))]

def wrotdist(froml, tol):
    n = len(froml)
    for shift in range(n):
        rotated = froml[-shift:] + froml[:-shift]
        if rotated == tol:
            weight = shift * 3
            totweight = n * 3
            return weight if weight <= totweight // 2 else weight - totweight
    return None

def lmr(inlayer, lilayer):
    variants = arots(lilayer)
    for i, var in enumerate(variants):
        if inlayer == var:
            rot = i * 3
            return rot if rot <= 6 else rot - 12
    return None

def cofalg(tinputstr, binputstr, toplist, botlist, alglist):
    tinput = tinputstr.split()
    binput = binputstr.split()

    for idx in range(len(toplist)):
        topvar = arots(toplist[idx])
        botvar = arots(botlist[idx])

        for i, trot in enumerate(topvar):
            if tinput == trot:
                for j, brot in enumerate(botvar):
                    if binput == brot:
                        tfix = (-i * 3) % 12
                        if tfix > 6:
                            tfix -= 12
                        bfix = (-j * 3) % 12
                        if bfix > 6:
                            bfix -= 12
                        return f"({tfix},{bfix})    {alglist[idx]}"
    return "lmao"


toplist4 = ["y y y y","y w w y","y w y w","y y y w","y w w y","y w y w","w w w w","w w w y"]
botlist4 = ["w w w w","y w w y","w y w y","w w w y","y w y w","w y y w","y y y y","y y y w"]
alglist4 = [" ","(1,0) / (-1,0)","(1,0) / (3,3) / (-1,0)","(1,0) / (3,0) / (-1,0)","(1,0) / (0,3) / (0,3) / (-1,0)","(1,0) / (3,0) / (3,0) / (-1,0)","(1,0) / (6,6) / (-1,0)","(1,0) / (3,0) / (-1,0)    (1,0) / (6,6) / (-1,0)"]

topinput4 = input("Add meg a felső réteg sarkainak színeit (pl.: y w w y): ")
botinput4 = input("Add meg az alsó réteg sarkainak színeit (pl.: y w y w): ")

res = cofalg(topinput4, botinput4, toplist4, botlist4, alglist4)
print(res)

t1=t2=t3=t4=t5=t6=t7=t8=t9=t10=t11=t12=t13=t14=t15=t16=t17=t18=t19=t20=t21 = "dimgray"
b1=b2=b3=b4=b5=b6=b7=b8=b9=b10=b11=b12=b13=b14=b15=b16=b17=b18=b19=b20=b21 = "dimgray"
t11=b11="black"

ctput4 = topinput4.split()
cbput4 = botinput4.split()
t15 = ctput4[0]
t17 = ctput4[1]
t7 = ctput4[2]
t5 = ctput4[3]
b7 = cbput4[0]
b5 = cbput4[1]
b15 = cbput4[2]
b17 = cbput4[3]

def orc4(c):
    return "orange" if c == "o" else c

tcol = [orc4(c) for c in [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17, t18, t19, t20, t21]]
bcol = [orc4(c) for c in [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21]]

rows = 5
cols = 5
cell_size = 1
gap = 2

def draw_grid(ax, start_x, start_y, colors):
    idx = 0
    for row in range(rows):
        for col in range(cols):
            if (row == 0 or row == 4) and (col < 1 or col > 3):
                continue
            rect = patches.Rectangle(
                (start_x + col * cell_size, start_y - row * cell_size),
                cell_size, cell_size,
                facecolor=colors[idx], edgecolor='black'
            )
            ax.add_patch(rect)
            idx += 1
            if idx >= 21:
                return
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.axis('off')
draw_grid(ax, start_x=0, start_y=0, colors=tcol)
draw_grid(ax, start_x=0, start_y=-(rows + gap), colors=bcol)
plt.xlim(-1, cols + 1)
plt.ylim(-(2*rows + gap), 1)
plt.show()

def rotate(lst, k):
    return lst[k:] + lst[:k]

def caroin(k):
    rmap = {0: 0, 1: -3, 2: 6, 3: 3}
    return rmap[k]

def eofalg(tinputstr, binputstr, toplist3, botlist3, alglist3):
    topinput3 = tinputstr.strip()
    botinput3 = binputstr.strip()
    tinput3 = topinput3.replace(" ", "")
    binput3 = botinput3.replace(" ", "")

    found = False

    for i in range(len(toplist3)):
        toppat = toplist3[i].replace(" ", "")
        botpat = botlist3[i].replace(" ", "")
        alg = alglist3[i]

        for tops in range(4):
            rott = rotate(toppat, tops)
            for bots in range(4):
                rotb = rotate(botpat, bots)

                if rott == tinput3 and rotb == binput3:
                    topr = caroin(tops)
                    botr = caroin(bots)
                    print(f"({topr},{botr})    {alg}")
                    found = True
                    break

            if found:
                break
    if not found:
        print("lmao")

toplist3 = ["y y y y","y w y y","w y y w","w y w y","y y w w","w y w y","w w y w","w w w w"]
botlist3 = ["w w w w","w w y w","y w w y","w y y w","y w y w","y w y w","y y y w","y y y y"]
alglist3 = ["","(1,0) / (3,0) / (3,0) / (-1,-1) / (-2,1) / (-3,0) /","(1,0) / (3,0) / (-1,-1) / (-3,0) / (0,1)","(0,-1) / (0,-3) / (0,-3) / (1,1) / (-1,2) / (1,4) / (-1,0)","(1,0) / (3,0) / (3,0) / (-1,-1) / (-2,1) / (-4,-1) / (1,0)","(1,0) / (-1,-1) / (0,1)","(0,-1) / (3,0) / (3,0) / (1,1) / (-3,0) / (-3,0) /","(1,0) / (-1,-1) / (3,3) / (1,1) / (-1,0)"]

topinput3 = input("Add meg a felső réteg éleinek színeit (pl.: y w w y): ")
botinput3 = input("Add meg az alsó réteg éleinek színeit (pl.: y w y w): ")

eofalg(topinput3, botinput3, toplist3, botlist3, alglist3)

t1=t2=t3=t4=t5=t6=t7=t8=t9=t10=t11=t12=t13=t14=t15=t16=t17=t18=t19=t20=t21 = "dimgray"
b1=b2=b3=b4=b5=b6=b7=b8=b9=b10=b11=b12=b13=b14=b15=b16=b17=b18=b19=b20=b21 = "dimgray"
t11=b11="black"

ctput3 = topinput3.split()
cbput3 = botinput3.split()
t16 = ctput3[0]
t12 = ctput3[1]
t6 = ctput3[2]
t10 = ctput3[3]
b6 = cbput3[0]
b10 = cbput3[1]
b16 = cbput3[2]
b12 = cbput3[3]
def orc3(c):
    return "orange" if c == "o" else c

tcol = [orc3(c) for c in [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17, t18, t19, t20, t21]]
bcol = [orc3(c) for c in [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21]]

rows = 5
cols = 5
cell_size = 1
gap = 2

def draw_grid(ax, start_x, start_y, colors):
    idx = 0
    for row in range(rows):
        for col in range(cols):
            if (row == 0 or row == 4) and (col < 1 or col > 3):
                continue
            rect = patches.Rectangle(
                (start_x + col * cell_size, start_y - row * cell_size),
                cell_size, cell_size,
                facecolor=colors[idx], edgecolor='black'
            )
            ax.add_patch(rect)
            idx += 1
            if idx >= 21:
                return
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.axis('off')
draw_grid(ax, start_x=0, start_y=0, colors=tcol)
draw_grid(ax, start_x=0, start_y=-(rows + gap), colors=bcol)
plt.xlim(-1, cols + 1)
plt.ylim(-(2*rows + gap), 1)
plt.show()

ccycle2 = {'o': 'b', 'b': 'r', 'r': 'g', 'g': 'o'}

def rotc(piece):
    return ''.join(ccycle2.get(c, c) for c in piece)

def cvariants(layer):
    vars = [layer]
    for _ in range(3):
        newlay = [rotc(p) for p in vars[-1]]
        vars.append(newlay)
    return vars

def rotlayer(layer, steps):
    return np.roll(layer, -steps).tolist()

def avariants(layerstr):
    layer = layerstr.split()
    vars_ = []
    for colorvar in cvariants(layer):
        for i in range(len(layer)):
            rotated = rotlayer(colorvar, i)
            vars_.append(rotated)
    return vars_

def wrotdist(froml, tol):
    n = len(froml)
    for shift in range(n):
        rotd = froml[-shift:] + froml[:-shift]
        if rotd == tol:
            weight = shift * 3
            totweight = n * 3
            return weight if weight <= totweight // 2 else weight - totweight
    return None

def epfalg(topnpstr, botnpstr, toplist, botlist, alglist):
    topnp = topnpstr.split()
    botnp = botnpstr.split()

    for idx in range(len(toplist)):
        topvar = avariants(toplist[idx])
        botvar = avariants(botlist[idx])

        for i, top_var in enumerate(topvar):
            if topnp == top_var:
                for j, bot_var in enumerate(botvar):
                    if botnp == bot_var:
                        alg = alglist[idx]
                        if alg.strip() == "":
                            return ""

                        topturn = wrotdist(top_var, toplist[idx].split())
                        botturn = wrotdist(bot_var, botlist[idx].split())
                        return f"({topturn},{botturn})    {alg}"

    return "lmao"

toplist2 = ["ybo yog yrb ygr","yog ybo yrb ygr","ybo yog yrb ygr","yrb ybo yog ygr","yrb ybo yog ygr","yog ybo yrb ygr","yog yrb ybo ygr","yrb ybo yog ygr","yog ybo yrb ygr"]
botlist2 = ["wob wgo wrg wbr","wob wgo wbr wrg","wob wgo wbr wrg","wob wrg wgo wbr","wob wgo wrg wbr","wrg wgo wob wbr","wrg wgo wob wbr","wrg wgo wob wbr","wob wgo wrg wbr"]
alglist2 = ["/ (3,-3) / (3,0) / (-3,0) / (0,3) / (-3,0) /","/ (3,-3) / (0,3) / (-3,0) / (3,0) / (-3,0) /","/ (-3,0) / (3,3) / (0,-3) /","/ (3,0) / (-3,0) / (3,0) / (-3,0) /","/ (3,3) / (3,0) / (3,3) / (3,0) / (3,3) /","/ (3,3) / (0,3) / (3,3) / (0,3) / (3,3) /","/ (0,3) / (0,-3) / (0,3) / (0,-3) /","/ (3,-3) / (3,-3) /",""]

topinput2 = input("Add meg a felső réteg sarkait (pl.: ybo yog yrb ygr): ")
botinput2 = input("Add meg az alsó réteg sarkait (pl.: wob wgo wrg wbr): ")

epalg = epfalg(topinput2, botinput2, toplist2, botlist2, alglist2)
print(epalg)

t1=t2=t3=t4=t5=t6=t7=t8=t9=t10=t11=t12=t13=t14=t15=t16=t17=t18=t19=t20=t21 = "dimgray"
b1=b2=b3=b4=b5=b6=b7=b8=b9=b10=b11=b12=b13=b14=b15=b16=b17=b18=b19=b20=b21 = "dimgray"
t11=b11="black"

ctput2 = topinput2.split()
cbput2 = botinput2.split()
t15=ctput2[0][0]
t19=ctput2[0][1]
t14=ctput2[0][2]
t17=ctput2[1][0]
t18=ctput2[1][1]
t21=ctput2[1][2]
t7=ctput2[2][0]
t3=ctput2[2][1]
t8=ctput2[2][2]
t5=ctput2[3][0]
t4=ctput2[3][1]
t1=ctput2[3][2]
b7=cbput2[0][0]
b3=cbput2[0][1]
b8=cbput2[0][2]
b5=cbput2[1][0]
b4=cbput2[1][1]
b1=cbput2[1][2]
b15=cbput2[2][0]
b19=cbput2[2][1]
b14=cbput2[2][2]
b17=cbput2[3][0]
b18=cbput2[3][1]
b21=cbput2[3][2]

def orc2(c):
    return "orange" if c == "o" else c

tcol = [orc2(c) for c in [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17, t18, t19, t20, t21]]
bcol = [orc2(c) for c in [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21]]

rows = 5
cols = 5
cell_size = 1
gap = 2

def draw_grid(ax, start_x, start_y, colors):
    idx = 0
    for row in range(rows):
        for col in range(cols):
            if (row == 0 or row == 4) and (col < 1 or col > 3):
                continue
            rect = patches.Rectangle(
                (start_x + col * cell_size, start_y - row * cell_size),
                cell_size, cell_size,
                facecolor=colors[idx], edgecolor='black'
            )
            ax.add_patch(rect)
            idx += 1
            if idx >= 21:
                return
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.axis('off')
draw_grid(ax, start_x=0, start_y=0, colors=tcol)
draw_grid(ax, start_x=0, start_y=-(rows + gap), colors=bcol)
plt.xlim(-1, cols + 1)
plt.ylim(-(2*rows + gap), 1)
plt.show()

ccycle1 = {'o': 'b', 'b': 'r', 'r': 'g', 'g': 'o'}

def rotc(piece):
    return ''.join(ccycle1.get(c, c) for c in piece)

def cvariants(layer):
    vars = [layer]
    for _ in range(3):
        newlay = [rotc(p) for p in vars[-1]]
        vars.append(newlay)
    return vars

def rotl(layer, stps):
    return np.roll(layer, -stps).tolist()

def avariants(layerstr):
    layer = layerstr.split()
    vars_ = []
    for colorvar in cvariants(layer):
        for i in range(4):
            rotd = rotl(colorvar, 2 * i)
            vars_.append(rotd)
    return vars_

def parsel(layerstr):
    return layerstr.split()

def wrotdist(froml, tol):
    n = len(froml)
    for shift in range(n):
        rotd_ = froml[-shift:] + froml[:-shift]
        if rotd_ == tol:
            weight = 0
            for i in range(shift):
                ptype = froml[-i-1]
                weight += 2 if len(ptype) == 3 else 1
            totweight = sum(2 if len(p) == 3 else 1 for p in froml)
            return weight if weight <= totweight // 2 else weight - totweight
    return None

def edgepermseek(topnpstr, botnpstr, toplist, botlist, alglist):
    topnp = parsel(topnpstr)
    botnp = parsel(botnpstr)

    for i in range(len(toplist)):
        topvar = avariants(toplist[i])
        botvar = avariants(botlist[i])

        for ti, top_var in enumerate(topvar):
            if topnp == top_var:
                for bi, bot_var in enumerate(botvar):
                    if botnp == bot_var:
                        tbase = parsel(toplist[i])
                        bbase = parsel(botlist[i])

                        tturn = wrotdist(topnp, tbase)
                        bturn = wrotdist(botnp, bbase)

                        turn = f"({tturn},{bturn})"
                        alg = alglist[i]

                        fix = "" if topnp[0][1] == 'o' else "Forgasd a helyükre a felső és alsó rétegeket!"
                        return f"{turn}    {alg}    {fix}"

    return "lmao"

toplist = ["yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yo ybo yb yrb yr ygr yg","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yg ybo yb yrb yr ygr yo","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yo ybo yg yrb yr ygr yb","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yg ybo yb yrb yo ygr yr","yog yr ybo yb yrb yg ygr yo","yog yr ybo yb yrb yg ygr yo","yog yr ybo yb yrb yg ygr yo
topinput1 = input("Add meg a felső réteg összes elemét (pl.: yog yo ybo yb yrb yr ygr yg): ")
botinput1 = input("Add meg az alsó réteg összes elemét (pl.: wob wo wgo wg wrg wr wbr wb): ")

epalg = edgepermseek(topinput1, botinput1, toplist, botlist, alglist)
print(epalg)

t1=t2=t3=t4=t5=t6=t7=t8=t9=t10=t11=t12=t13=t14=t15=t16=t17=t18=t19=t20=t21 = "dimgray"
b1=b2=b3=b4=b5=b6=b7=b8=b9=b10=b11=b12=b13=b14=b15=b16=b17=b18=b19=b20=b21 = "dimgray"
t11=b11="black"

ctput1 = topinput1.split()
cbput1 = botinput1.split()
t15=ctput1[0][0]
t19=ctput1[0][1]
t14=ctput1[0][2]
t16=ctput1[1][0]
t20=ctput1[1][1]
t17=ctput1[2][0]
t18=ctput1[2][1]
t21=ctput1[2][2]
t12=ctput1[3][0]
t13=ctput1[3][1]
t7=ctput1[4][0]
t3=ctput1[4][1]
t8=ctput1[4][2]
t6=ctput1[5][0]
t2=ctput1[5][1]
t5=ctput1[6][0]
t4=ctput1[6][1]
t1=ctput1[6][2]
t10=ctput1[7][0]
t9=ctput1[7][1]
b7=cbput1[0][0]
b3=cbput1[0][1]
b8=cbput1[0][2]
b6=cbput1[1][0]
b2=cbput1[1][1]
b5=cbput1[2][0]
b4=cbput1[2][1]
b1=cbput1[2][2]
b10=cbput1[3][0]
b9=cbput1[3][1]
b15=cbput1[4][0]
b19=cbput1[4][1]
b14=cbput1[4][2]
b16=cbput1[5][0]
b20=cbput1[5][1]
b17=cbput1[6][0]
b18=cbput1[6][1]
b21=cbput1[6][2]
b12=cbput1[7][0]
b13=cbput1[7][1]

def orc1(c):
    return "orange" if c == "o" else c

tcol = [orc1(c) for c in [t1, t2, t3, t4, t5, t6, t7, t8, t9, t10, t11, t12, t13, t14, t15, t16, t17, t18, t19, t20, t21]]
bcol = [orc1(c) for c in [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10, b11, b12, b13, b14, b15, b16, b17, b18, b19, b20, b21]]

rows = 5
cols = 5
cell_size = 1
gap = 2

def draw_grid(ax, start_x, start_y, colors):
    idx = 0
    for row in range(rows):
        for col in range(cols):
            if (row == 0 or row == 4) and (col < 1 or col > 3):
                continue
            rect = patches.Rectangle(
                (start_x + col * cell_size, start_y - row * cell_size),
                cell_size, cell_size,
                facecolor=colors[idx], edgecolor='black'
            )
            ax.add_patch(rect)
            idx += 1
            if idx >= 21:
                return
fig, ax = plt.subplots()
ax.set_aspect('equal')
ax.axis('off')
draw_grid(ax, start_x=0, start_y=0, colors=tcol)
draw_grid(ax, start_x=0, start_y=-(rows + gap), colors=bcol)
plt.xlim(-1, cols + 1)
plt.ylim(-(2*rows + gap), 1)
plt.show()


slash = input("A középső réteg helyes állapotban van?(y/n)")
if slash == "n":
  print("/ (6,0) / (6,0) / (6,0)")
